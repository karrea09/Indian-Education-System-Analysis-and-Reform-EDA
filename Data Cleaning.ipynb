# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df2015 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2015.xlsx")

# %%
df2016 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2016.xlsx")

# %%
df2015
# Out:
#               State Education Level  Gender  2015 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                         189
# 1    Andhra Pradesh         Primary  Female                          93
# 2    Andhra Pradesh          Middle    Male                         305
# 3    Andhra Pradesh          Middle  Female                         162
# 4    Andhra Pradesh       Secondary    Male                         443
# ..              ...             ...     ...                         ...
# 387     West Bengal         Diploma  Female                           4
# 388     West Bengal        Graduate    Male                         120
# 389     West Bengal        Graduate  Female                          66
# 390     West Bengal   Post-Graduate    Male                           2
# 391     West Bengal   Post-Graduate  Female                           0
#
#      2015 Over-Ambitious Parents  2015 Securing Pass Mark
# ...

# %%
df2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        392 non-null    object
#  1   Education Level              392 non-null    object
#  2   Gender                       392 non-null    object
#  3   2015 Entrance Exam Failure   392 non-null    int64
#  4   2015 Over-Ambitious Parents  392 non-null    int64
#  5   2015 Securing Pass Mark      392 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.5+ KB

# %%
df2016.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2016 Entrance Exam Failure     0
# 2016 Over-Ambitious Parents    0
# 2016 Securing Pass Mark        0
# dtype: int64

# %%
df2015["2015 Securing Pass Mark"]=df2015["2015 Over-Ambitious Parents"].astype("int")

# %%
df2016["Education Level"].unique()
# Out:
# array(['Diploma', 'Graduate', 'Hr.Secondary', 'Secondary', 'Middle',
#        'Primary', 'Post-Graduate'], dtype=object)

# %%
df2016["State"] = df2016["State"].str.title()

# %%
df2015["State"].ffill(inplace = True )

# %%
(df2015["Education Level"] =='Post Graduate and above').sum()
# Out:
# np.int64(0)

# %%
df2016["Education Level"].replace('Matric / Secondary',"Secondary",inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/2603034692.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2016["Education Level"].replace('Matric / Secondary',"Secondary",inplace = True)

# %%
df2013["State"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
a2015_2016 = pd.concat([df2015,df2016],axis = 1)

# %%
a2015_2016.drop(a2015_2016.index[392:],inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/2539562691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2015_2016.drop(a2015_2016.index[392:],inplace = True)

# %%
a2015_2016 = a2015_2016.iloc[:,~a2015_2016.columns.duplicated()]

# %%
m.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2013 Entrance Exam Failure     0
# 2013 Over-Ambitious Parents    0
# 2013 Securing Pass Mark        0
# 2014 Entrance Exam Failure     0
# 2014 Over-Ambitious Parents    0
# 2014 Securing Pass Mark        0
# dtype: int64

# %%
sns.histplot(data = m, x = "2014 Securing Pass Mark",kde = True)
# Out:
# <Axes: xlabel='2014 Securing Pass Mark', ylabel='Count'>

# %%
m["2014 Securing Pass Mark"].mean()
# Out:
# np.float64(40.50642673521851)

# %%
m["2014 Securing Pass Mark"].fillna(8,inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1132940737.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   m["2014 Securing Pass Mark"].fillna(8,inplace = True)
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1132940737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
m.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2013 Entrance Exam Failure     0
# 2013 Over-Ambitious Parents    0
# 2013 Securing Pass Mark        0
# 2014 Entrance Exam Failure     0
# 2014 Over-Ambitious Parents    0
# 2014 Securing Pass Mark        0
# dtype: int64

# %%
m2013_2014
# Out:
#               State Education Level  Gender  2013 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                         948
# 1    Andhra Pradesh         Primary  Female                         446
# 2    Andhra Pradesh          Middle    Male                         880
# 3    Andhra Pradesh          Middle  Female                         380
# 4    Andhra Pradesh       Secondary    Male                         803
# ..              ...             ...     ...                         ...
# 384     West Bengal         Diploma  Female                           8
# 385     West Bengal        Graduate    Male                          85
# 386     West Bengal        Graduate  Female                          42
# 387     West Bengal   Post-Graduate    Male                          13
# 388     West Bengal   Post-Graduate  Female                           6
#
#      2013 Over-Ambitious Parents  2013 Securing Pass Mark  \
# ...

# %%
a2015_2016.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2015 Entrance Exam Failure     0
# 2015 Over-Ambitious Parents    0
# 2015 Securing Pass Mark        0
# 2016 Entrance Exam Failure     0
# 2016 Over-Ambitious Parents    0
# 2016 Securing Pass Mark        0
# dtype: int64

# %%
a2015_2016["2016 Securing Pass Mark"].median()
# Out:
# np.float64(12.0)

# %%
a2015_2016["2016 Securing Pass Mark"].fillna(12,inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1728695619.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a2015_2016["2016 Securing Pass Mark"].fillna(12,inplace = True)
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1728695619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
a2015_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        392 non-null    object
#  1   Education Level              392 non-null    object
#  2   Gender                       392 non-null    object
#  3   2015 Entrance Exam Failure   392 non-null    int64
#  4   2015 Over-Ambitious Parents  392 non-null    int64
#  5   2015 Securing Pass Mark      392 non-null    int64
#  6   2016 Entrance Exam Failure   392 non-null    int64
#  7   2016 Over-Ambitious Parents  392 non-null    int64
#  8   2016 Securing Pass Mark      392 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 27.7+ KB

# %%
a2015_2016["2016 Securing Pass Mark"]=a2015_2016["2016 Securing Pass Mark"].astype("int")
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/2861297293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2015_2016["2016 Securing Pass Mark"]=a2015_2016["2016 Securing Pass Mark"].astype("int")

# %%
m2013_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    int64
#  4   2013 Over-Ambitious Parents  389 non-null    int64
#  5   2013 Securing Pass Mark      389 non-null    int64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    float64
#  8   2014 Securing Pass Mark      389 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 27.5+ KB

# %%
a2013_2016 = pd.concat([m2013_2014,a2015_2016],axis = 1)

# %%
a2013_2016.drop(a2013_2016.index[389:],inplace = True)

# %%
a2013_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    float64
#  4   2013 Over-Ambitious Parents  389 non-null    float64
#  5   2013 Securing Pass Mark      389 non-null    float64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    float64
#  8   2014 Securing Pass Mark      389 non-null    float64
#  9   State                        389 non-null    object
#  10  Education Level              389 non-null    object
#  11  Gender                       389 non-null    object
#  12  2015 Entrance Exam Failure   389 non-null    int64
# ...

# %%
a2013_2016 = a2013_2016.iloc[:,~a2013_2016.columns.duplicated()]

# %%
a2013_2016
# Out:
#               State Education Level  Gender  2013 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                       948.0
# 1    Andhra Pradesh         Primary  Female                       446.0
# 2    Andhra Pradesh          Middle    Male                       880.0
# 3    Andhra Pradesh          Middle  Female                       380.0
# 4    Andhra Pradesh       Secondary    Male                       803.0
# ..              ...             ...     ...                         ...
# 384     West Bengal         Diploma  Female                         8.0
# 385     West Bengal        Graduate    Male                        85.0
# 386     West Bengal        Graduate  Female                        42.0
# 387     West Bengal   Post-Graduate    Male                        13.0
# 388     West Bengal   Post-Graduate  Female                         6.0
#
#      2013 Over-Ambitious Parents  2013 Securing Pass Mark  \
# ...

# %%
a2013_2016.to_excel('a2013_2016.xlsx', index=False)

# %%
# instead of pd.read_csv(...)
df = pd.read_excel('/Users/ashokkarre/a2013_2016.xlsx')

# %%
df
# Out:
#               State Education Level  Gender  2013 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                         948
# 1    Andhra Pradesh         Primary  Female                         446
# 2    Andhra Pradesh          Middle    Male                         880
# 3    Andhra Pradesh          Middle  Female                         380
# 4    Andhra Pradesh       Secondary    Male                         803
# ..              ...             ...     ...                         ...
# 384     West Bengal         Diploma  Female                           8
# 385     West Bengal        Graduate    Male                          85
# 386     West Bengal        Graduate  Female                          42
# 387     West Bengal   Post-Graduate    Male                          13
# 388     West Bengal   Post-Graduate  Female                           6
#
#      2013 Over-Ambitious Parents  2013 Securing Pass Mark  \
# ...

# %%
# requires openpyxl (pip install openpyxl)
df.to_excel('/Users/ashokkarre/downloads/a2013_2016.xlsx', index=False, engine='openpyxl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    int64
#  4   2013 Over-Ambitious Parents  389 non-null    int64
#  5   2013 Securing Pass Mark      389 non-null    int64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    int64
#  8   2014 Securing Pass Mark      389 non-null    int64
#  9   2015 Entrance Exam Failure   389 non-null    int64
#  10  2015 Over-Ambitious Parents  389 non-null    int64
#  11  2015 Securing Pass Mark      389 non-null    int64
#  12  2016 Entrance Exam Failure   389 non-null    int64
# ...

# %%
df["2015 Entrance Exam Failure"].isnull().sum()
# Out:
# np.int64(0)

# %%
df2017 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2017.xlsx")

# %%
df2017
# Out:
#               State           Education Level  Gender  \
# 0    Andhra Pradesh   Primary (upto class IV)    Male
# 1    Andhra Pradesh   Primary (upto class IV)  Female
# 2    Andhra Pradesh  Middle (upto class VIII)    Male
# 3    Andhra Pradesh  Middle (upto class VIII)  Female
# 4    Andhra Pradesh          Matric/Secondary    Male
# ..              ...                       ...     ...
# 356     West Bengal               Diploma/ITI  Female
# 357     West Bengal        Graduate and above    Male
# 358     West Bengal        Graduate and above  Female
# 359     West Bengal  Professionals (MBA etc.)    Male
# 360     West Bengal  Professionals (MBA etc.)  Female
#
#      2017 Entrance Exam Failure  2017 Over-Ambitious Parents  \
# 0                           574                          344
# 1                           127                           76
# 2                           470                          282
# 3                           129                           77
# ...

# %%
df2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        361 non-null    object
#  1   Education Level              361 non-null    object
#  2   Gender                       361 non-null    object
#  3   2017 Entrance Exam Failure   361 non-null    int64
#  4   2017 Over-Ambitious Parents  361 non-null    int64
#  5   2017 Securing Pass Mark      361 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 17.1+ KB

# %%
df2017["State"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttarakhand', 'Uttar Pradesh',
#        'West Bengal'], dtype=object)

# %%
df2017["State"]=df2017["State"].str.title()

# %%
df2017["Education Level"].replace('Professionals (MBA etc.)',"Post-Graduate",inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1934219276.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2017["Education Level"].replace('Professionals (MBA etc.)',"Post-Graduate",inplace = True)

# %%
df2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        361 non-null    object
#  1   Education Level              361 non-null    object
#  2   Gender                       361 non-null    object
#  3   2017 Entrance Exam Failure   361 non-null    int64
#  4   2017 Over-Ambitious Parents  361 non-null    int64
#  5   2017 Securing Pass Mark      361 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 17.1+ KB

# %%
df2018 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2018.xlsx")

# %%
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        346 non-null    object
#  1   Education Level              346 non-null    object
#  2   Gender                       346 non-null    object
#  3   2018 Entrance Exam Failure   346 non-null    int64
#  4   2018 Over-Ambitious Parents  346 non-null    int64
#  5   2018 Securing Pass Mark      346 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 16.3+ KB

# %%
df2018["State"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
df2018["State"]=df["State"].str.title()

# %%
df2018["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df2018["Education Level"].replace('Professional Education',"Post-Graduate",inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/3934473789.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2018["Education Level"].replace('Professional Education',"Post-Graduate",inplace = True)

# %%
df2018.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2018 Entrance Exam Failure     0
# 2018 Over-Ambitious Parents    0
# 2018 Securing Pass Mark        0
# dtype: int64

# %%
a2017_2018 = pd.concat([df2017,df2018],axis = 1)

# %%
a2017_2018 = a2017_2018.iloc[:,~a2017_2018.columns.duplicated()]

# %%
a2017_2018.isnull().sum()
# Out:
# State                           0
# Education Level                 0
# Gender                          0
# 2017 Entrance Exam Failure      0
# 2017 Over-Ambitious Parents     0
# 2017 Securing Pass Mark         0
# 2018 Entrance Exam Failure     15
# 2018 Over-Ambitious Parents    15
# 2018 Securing Pass Mark        15
# dtype: int64

# %%
a2017_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        361 non-null    object
#  1   Education Level              361 non-null    object
#  2   Gender                       361 non-null    object
#  3   2017 Entrance Exam Failure   361 non-null    int64
#  4   2017 Over-Ambitious Parents  361 non-null    int64
#  5   2017 Securing Pass Mark      361 non-null    int64
#  6   2018 Entrance Exam Failure   361 non-null    float64
#  7   2018 Over-Ambitious Parents  361 non-null    float64
#  8   2018 Securing Pass Mark      361 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 25.5+ KB

# %%
a2017_2018["2018 Securing Pass Mark"].median()
# Out:
# np.float64(25.0)

# %%
a2017_2018["2018 Securing Pass Mark"].fillna(25,inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/3274443038.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a2017_2018["2018 Securing Pass Mark"].fillna(25,inplace = True)

# %%
a2017_2018
# Out:
#               State Education Level  Gender  2017 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                         574
# 1    Andhra Pradesh         Primary  Female                         127
# 2    Andhra Pradesh          Middle    Male                         470
# 3    Andhra Pradesh          Middle  Female                         129
# 4    Andhra Pradesh       Secondary    Male                         617
# ..              ...             ...     ...                         ...
# 356     West Bengal         Diploma  Female                           3
# 357     West Bengal        Graduate    Male                         225
# 358     West Bengal        Graduate  Female                          85
# 359     West Bengal   Post-Graduate    Male                           0
# 360     West Bengal   Post-Graduate  Female                           0
#
#      2017 Over-Ambitious Parents  2017 Securing Pass Mark  \
# ...

# %%
df2019 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2019.xlsx")

# %%
df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        376 non-null    object
#  1   Education Level              376 non-null    object
#  2   Gender                       376 non-null    object
#  3   2019 Entrance Exam Failure   376 non-null    int64
#  4   2019 Over-Ambitious Parents  376 non-null    int64
#  5   2019 Securing Pass Mark      376 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 17.8+ KB

# %%
df2019["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df2019["State"]=df2019["State"].str.title()

# %%
df2019["Education Level"].replace('Professionals',"Post-Graduate",inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/2800742387.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2019["Education Level"].replace('Professionals',"Post-Graduate",inplace = True)

# %%
df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        376 non-null    object
#  1   Education Level              376 non-null    object
#  2   Gender                       376 non-null    object
#  3   2019 Entrance Exam Failure   376 non-null    int64
#  4   2019 Over-Ambitious Parents  376 non-null    int64
#  5   2019 Securing Pass Mark      376 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 17.8+ KB

# %%
df2020 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2020.xlsx")

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        390 non-null    object
#  1   Education Level              390 non-null    object
#  2   Gender                       390 non-null    object
#  3   2020 Entrance Exam Failure   390 non-null    int64
#  4   2020 Over-Ambitious Parents  390 non-null    int64
#  5   2020 Securing Pass Mark      390 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.4+ KB

# %%
df2020["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df2020["State"] = df2020["State"].str.title()

# %%
df2020["Education Level"].replace('Diploma/ITI',"Diploma",inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/3639696133.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2020["Education Level"].replace('Diploma/ITI',"Diploma",inplace = True)

# %%
m2019_20 = pd.concat([df2019,df2020],axis = 1)

# %%
m2019_20[376:]
# Out:
#     State Education Level Gender  2019 Entrance Exam Failure  \
# 376   NaN             NaN    NaN                         NaN
# 377   NaN             NaN    NaN                         NaN
# 378   NaN             NaN    NaN                         NaN
# 379   NaN             NaN    NaN                         NaN
# 380   NaN             NaN    NaN                         NaN
# 381   NaN             NaN    NaN                         NaN
# 382   NaN             NaN    NaN                         NaN
# 383   NaN             NaN    NaN                         NaN
# 384   NaN             NaN    NaN                         NaN
# 385   NaN             NaN    NaN                         NaN
# 386   NaN             NaN    NaN                         NaN
# 387   NaN             NaN    NaN                         NaN
# 388   NaN             NaN    NaN                         NaN
# 389   NaN             NaN    NaN                         NaN
#
# ...

# %%
m2019_20.drop(m2019_20.index[376:],inplace = True)

# %%
m2019_20 = m2019_20.iloc[:,~m2019_20.columns.duplicated()]

# %%
m2019_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        376 non-null    object
#  1   Education Level              376 non-null    object
#  2   Gender                       376 non-null    object
#  3   2019 Entrance Exam Failure   376 non-null    float64
#  4   2019 Over-Ambitious Parents  376 non-null    float64
#  5   2019 Securing Pass Mark      376 non-null    float64
#  6   2020 Entrance Exam Failure   376 non-null    int64
#  7   2020 Over-Ambitious Parents  376 non-null    int64
#  8   2020 Securing Pass Mark      376 non-null    int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 26.6+ KB

# %%
m2019_20.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2019 Entrance Exam Failure     0
# 2019 Over-Ambitious Parents    0
# 2019 Securing Pass Mark        0
# 2020 Entrance Exam Failure     0
# 2020 Over-Ambitious Parents    0
# 2020 Securing Pass Mark        0
# dtype: int64

# %%
a2017_2018
# Out:
#               State Education Level  Gender  2017 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                         574
# 1    Andhra Pradesh         Primary  Female                         127
# 2    Andhra Pradesh          Middle    Male                         470
# 3    Andhra Pradesh          Middle  Female                         129
# 4    Andhra Pradesh       Secondary    Male                         617
# ..              ...             ...     ...                         ...
# 356     West Bengal         Diploma  Female                           3
# 357     West Bengal        Graduate    Male                         225
# 358     West Bengal        Graduate  Female                          85
# 359     West Bengal   Post-Graduate    Male                           0
# 360     West Bengal   Post-Graduate  Female                           0
#
#      2017 Over-Ambitious Parents  2017 Securing Pass Mark  \
# ...

# %%
a17_20 = pd.concat([a2017_2018,m2019_20],axis = 1)

# %%
a17_20.drop(a17_20.index[361: ],inplace = True)

# %%
df17_20 = a17_20.iloc[:,~a17_20.columns.duplicated()]

# %%
df17_20
# Out:
#               State Education Level  Gender  2017 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                       574.0
# 1    Andhra Pradesh         Primary  Female                       127.0
# 2    Andhra Pradesh          Middle    Male                       470.0
# 3    Andhra Pradesh          Middle  Female                       129.0
# 4    Andhra Pradesh       Secondary    Male                       617.0
# ..              ...             ...     ...                         ...
# 356     West Bengal         Diploma  Female                         3.0
# 357     West Bengal        Graduate    Male                       225.0
# 358     West Bengal        Graduate  Female                        85.0
# 359     West Bengal   Post-Graduate    Male                         0.0
# 360     West Bengal   Post-Graduate  Female                         0.0
#
#      2017 Over-Ambitious Parents  2017 Securing Pass Mark  \
# ...

# %%
a2013_2016
# Out:
#               State Education Level  Gender  2013 Entrance Exam Failure  \
# 0    Andhra Pradesh         Primary    Male                       948.0
# 1    Andhra Pradesh         Primary  Female                       446.0
# 2    Andhra Pradesh          Middle    Male                       880.0
# 3    Andhra Pradesh          Middle  Female                       380.0
# 4    Andhra Pradesh       Secondary    Male                       803.0
# ..              ...             ...     ...                         ...
# 384     West Bengal         Diploma  Female                         8.0
# 385     West Bengal        Graduate    Male                        85.0
# 386     West Bengal        Graduate  Female                        42.0
# 387     West Bengal   Post-Graduate    Male                        13.0
# 388     West Bengal   Post-Graduate  Female                         6.0
#
#      2013 Over-Ambitious Parents  2013 Securing Pass Mark  \
# ...

# %%
df20 = pd.concat([a2013_2016,df17_20],axis = 1)

# %%
df20 = df20.iloc[:,~df20.columns.duplicated()]

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    float64
#  4   2013 Over-Ambitious Parents  389 non-null    float64
#  5   2013 Securing Pass Mark      389 non-null    float64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    float64
#  8   2014 Securing Pass Mark      389 non-null    float64
#  9   2015 Entrance Exam Failure   389 non-null    int64
#  10  2015 Over-Ambitious Parents  389 non-null    int64
#  11  2015 Securing Pass Mark      389 non-null    int64
#  12  2016 Entrance Exam Failure   389 non-null    int64
# ...

# %%
df20.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2013 Entrance Exam Failure     0
# 2013 Over-Ambitious Parents    0
# 2013 Securing Pass Mark        0
# 2014 Entrance Exam Failure     0
# 2014 Over-Ambitious Parents    0
# 2014 Securing Pass Mark        0
# 2015 Entrance Exam Failure     0
# 2015 Over-Ambitious Parents    0
# 2015 Securing Pass Mark        0
# 2016 Entrance Exam Failure     0
# 2016 Over-Ambitious Parents    0
# 2016 Securing Pass Mark        0
# 2017 Entrance Exam Failure     0
# 2017 Over-Ambitious Parents    0
# 2017 Securing Pass Mark        0
# 2018 Entrance Exam Failure     0
# 2018 Over-Ambitious Parents    0
# 2018 Securing Pass Mark        0
# 2019 Entrance Exam Failure     0
# 2019 Over-Ambitious Parents    0
# 2019 Securing Pass Mark        0
# 2020 Entrance Exam Failure     0
# 2020 Over-Ambitious Parents    0
# 2020 Securing Pass Mark        0
# dtype: int64

# %%
df20["2020 Securing Pass Mark"].median()
# Out:
# np.float64(5.0)

# %%
df20["2020 Securing Pass Mark"].fillna(5,inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/2155772027.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df20["2020 Securing Pass Mark"].fillna(5,inplace = True)
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/2155772027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    float64
#  4   2013 Over-Ambitious Parents  389 non-null    float64
#  5   2013 Securing Pass Mark      389 non-null    float64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    float64
#  8   2014 Securing Pass Mark      389 non-null    float64
#  9   2015 Entrance Exam Failure   389 non-null    int64
#  10  2015 Over-Ambitious Parents  389 non-null    int64
#  11  2015 Securing Pass Mark      389 non-null    int64
#  12  2016 Entrance Exam Failure   389 non-null    int64
# ...

# %%
df2021 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2021.xlsx")

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        290 non-null    object
#  1   Education Level              290 non-null    object
#  2   Gender                       290 non-null    object
#  3   2021 Entrance Exam Failure   290 non-null    int64
#  4   2021 Over-Ambitious Parents  290 non-null    int64
#  5   2021 Securing Pass Mark      290 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 13.7+ KB

# %%
df2021["Education Level"].ffill(inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1233051019.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2021["Education Level"].ffill(inplace = True)

# %%
df2021["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["State"] = df2021["State"].str.title()

# %%
df2021["Education Level"].replace('Professional (MBA etc.)',"Post-Graduate",inplace = True)

# %%
df2021 = pd.concat([df20,df2021],axis = 1)

# %%
df2021 = df2021.iloc[:,~df2021.columns.duplicated()]

# %%
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    float64
#  4   2013 Over-Ambitious Parents  389 non-null    float64
#  5   2013 Securing Pass Mark      389 non-null    float64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    float64
#  8   2014 Securing Pass Mark      389 non-null    float64
#  9   2015 Entrance Exam Failure   389 non-null    int64
#  10  2015 Over-Ambitious Parents  389 non-null    int64
#  11  2015 Securing Pass Mark      389 non-null    int64
#  12  2016 Entrance Exam Failure   389 non-null    int64
# ...

# %%
df2021["2021 Securing Pass Mark"].median()
# Out:
# np.float64(19.5)

# %%
df2021["2021 Securing Pass Mark"].fillna(19,inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/3637283161.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2021["2021 Securing Pass Mark"].fillna(19,inplace = True)

# %%
df2022 = pd.read_excel(r"/Users/ashokkarre/Downloads/EDA Project/2022.xlsx")

# %%
df2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        392 non-null    object
#  1   Education Level              392 non-null    object
#  2   Gender                       392 non-null    object
#  3   2022 Entrance Exam Failure   392 non-null    int64
#  4   2022 Over-Ambitious Parents  392 non-null    int64
#  5   2022 Securing Pass Mark      392 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.5+ KB

# %%
df2022["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df2022["State"] = df2022["State"].str.title()

# %%
df2022["Education Level"].replace('Post-Graduation',"Post-Graduate",inplace = True)
# Out:
# /var/folders/j7/0v65189d0wvb271f8y24c1l40000gn/T/ipykernel_1465/1188458565.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2022["Education Level"].replace('Post-Graduation',"Post-Graduate",inplace = True)

# %%
df2022.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2022 Entrance Exam Failure     0
# 2022 Over-Ambitious Parents    0
# 2022 Securing Pass Mark        0
# dtype: int64

# %%
df22 = pd.concat([df2021,df2022],axis = 1)

# %%
df22.drop(df22.index[389:],inplace = True)

# %%
df22 = df22.iloc[:,~df22.columns.duplicated()]

# %%
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        389 non-null    object
#  1   Education Level              389 non-null    object
#  2   Gender                       389 non-null    object
#  3   2013 Entrance Exam Failure   389 non-null    float64
#  4   2013 Over-Ambitious Parents  389 non-null    float64
#  5   2013 Securing Pass Mark      389 non-null    float64
#  6   2014 Entrance Exam Failure   389 non-null    float64
#  7   2014 Over-Ambitious Parents  389 non-null    float64
#  8   2014 Securing Pass Mark      389 non-null    float64
#  9   2015 Entrance Exam Failure   389 non-null    float64
#  10  2015 Over-Ambitious Parents  389 non-null    float64
#  11  2015 Securing Pass Mark      389 non-null    float64
# ...

# %%
df22.isnull().sum()
# Out:
# State                          0
# Education Level                0
# Gender                         0
# 2013 Entrance Exam Failure     0
# 2013 Over-Ambitious Parents    0
# 2013 Securing Pass Mark        0
# 2014 Entrance Exam Failure     0
# 2014 Over-Ambitious Parents    0
# 2014 Securing Pass Mark        0
# 2015 Entrance Exam Failure     0
# 2015 Over-Ambitious Parents    0
# 2015 Securing Pass Mark        0
# 2016 Entrance Exam Failure     0
# 2016 Over-Ambitious Parents    0
# 2016 Securing Pass Mark        0
# 2017 Entrance Exam Failure     0
# 2017 Over-Ambitious Parents    0
# 2017 Securing Pass Mark        0
# 2018 Entrance Exam Failure     0
# 2018 Over-Ambitious Parents    0
# 2018 Securing Pass Mark        0
# 2019 Entrance Exam Failure     0
# 2019 Over-Ambitious Parents    0
# 2019 Securing Pass Mark        0
# 2020 Entrance Exam Failure     0
# 2020 Over-Ambitious Parents    0
# 2020 Securing Pass Mark        0
# 2021 Entrance Exam Failure     0
# ...

# %%
df22.to_excel('df22.xlsx', index=False)

# %%
# instead of pd.read_csv(...)
df22 = pd.read_excel('/Users/ashokkarre/df22.xlsx')

# %%
# requires openpyxl (pip install openpyxl)
df22.to_excel('/Users/ashokkarre/.xlsx', index=False, engine='openpyxl')
